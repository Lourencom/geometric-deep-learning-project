# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import argparse

args = argparse.Namespace(
    model_size="large",
    prompt_path="data/single_prompt.json",
    prompt_difficulty="medium",
    prompt_category=None,
    prompt_n_shots=None,
    output_dir="data/attn"
)

# %%
from attention import run_model, extract_attention, store_answer
from visualization import plot_attention_matrices

# %%
outputs, answer, prompt = run_model(args)
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.01s/it]
# `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True`. Falling back to eager attention. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.

# %%
attention_matrices = extract_attention(args, outputs)
answer_file = store_answer(args, answer, prompt)

# %%
print(len(attention_matrices))

# batch_size, n_heads, seq_len queries, seq_len keys
print(attention_matrices[0].shape)
# Out:
# 32
# (1, 32, 31, 31)

# %%
plot_attention_matrices(attention_matrices, aggregation="head")
# Out:
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
# (31, 31)
